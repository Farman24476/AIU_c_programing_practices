# %% [markdown]
# <a href="https://colab.research.google.com/github/Farman24476/AIU_c_programing_practices/blob/main/Lab_3_Intro_to_Dataframe_by_Farman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# ![](http://pandas.pydata.org/_static/pandas_logo.png)
# [Pandas](http://pandas.pydata.org/) is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series. Pandas is free software released under the three-clause BSD license. The name is derived from the term _panel data_, an econometrics term for multidimensional structured data sets.

# %% [markdown]
# ## DataFrames
#
#
# A data frame is like a table, with rows and columns (e.g., as in SQL or Excel).
# Except that :
#   - The rows can be indexed by something interesting (there is special support for labels like categorical and timeseries data).
#   - Cells can store any Python object. Like in SQL, columns must have a homogenous type.
#   - Instead of "NULL", the name for a non-existent value is "NA".  Unlike R, Python's data frames only support NAs in columns of some data types (basically: floating point numbers and 'objects') -- but this is mostly a non-issue (because it will "up-type" integers to float64, etc.)
#
# Each of a ```DataFrame```'s columns are an individual ```Series```, (more correctly, a dataframe is a dictionary of Series).  The entires series must have a homogenous type.

# %%
#import pandas library as pd
import pandas as pd
#import matplotlib library as plt
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Dataframe

# %% [markdown]
# ## 1. Merge two lists using zip function
# ## 2. Create a Dataframe using a list
# ## 3. Create a Dataframe using Series
# ## 4. Dataframe Functions
# ### a. df.head()
# ### b. df.tail()
# ### c. df.info()
# ### d. df.describe()
# ### e. df.T
# ### f. df['Area']
# ### g. type(df['Area'])
# ### h. df.sort_values('Area', ascending=False)
# ### i. df['Area'].sum()
# ### j. df['Area'][9:11].sum()
# ### k. Create a graph using matplot library

# %% [markdown]
# ## 1. Merge two lists using zip function

# %% [markdown]
# Example 1
#
# Let's make a dataset that consists of Malaysian States
# and the size of each state in $km^2$.  Let's try and rank
# the states of Malaysia by land area, and figure out if East
# Malaysia is larger or smaller than West Malaysia

# %% [markdown]
# Use the zip function to merge the two lists together

# %% [markdown]
# ## 2. Create a Dataframe using a list

# %% [markdown]
# ***df*** will be a ***DataFrame*** object. You can think of this object holding the contents of states in a format similar to a sql table or an excel spreadsheet. Lets take a look below at the contents inside ***df***.

# %% [markdown]
# ## 3. Create a Dataframe using Series

# %% [markdown]
# ## 4. Dataframe Functions

# %% [markdown]
# ### Dataframe from list

# %% [markdown]
# ### Dataframe from Series
#
# Exercise:
#
#
# *   Show the first five  rows
# *   Show the last five rows
#
#
# *   Show the info and description of the dataframe
# *   Calculate the sum of sales for all stores
#
#
# *   Calculate the amount spent by any two customers
# *   Plot suitable graph

# %%
States = ['johor','kedah','melaka','negari Sembilan',' pahang','perak','parlis','penang','']
area = [19210,9500,15099,1664,6686,36137,21035,821,1048,73,631,124450,8104,13035]


covid19=[16769,5253,2927,3078,11097,2663,5326,154,7225,471389,3499,55369,55369,1613]

# %%
State_area=zip(States,area)
State_area

# %%
State_area=list(zip(States,area))
State_area
# Out:
# [('johor', 19210),
#  ('kedah', 9500),
#  ('melaka', 15099),
#  ('negari Sembilan', 1664),
#  (' pahang', 6686),
#  ('perak', 36137),
#  ('parlis', 21035),
#  ('penang', 821),
#  ('', 1048)]

# %%
df1=pd.DataFrame(data=State_area, columns=['State','area'])

# %%
df1
# Out:
#              State   area
# 0            johor  19210
# 1            kedah   9500
# 2           melaka  15099
# 3  negari Sembilan   1664
# 4           pahang   6686
# 5            perak  36137
# 6           parlis  21035
# 7           penang    821
# 8                    1048

# %%
purchase_1 =pd.Series({'Name':'MD','Item Purchase':'Cat Food','Cost':22.50})
purchase_2 =pd.Series({'Name':'Farman','Item Purchase':'Dog Food','Cost':2.50})
purchase_3 =pd.Series({'Name':'Aidarus','Item Purchase':'CAt Food','Cost':20.50})
dfs=pd.DataFrame([purchase_1,purchase_2,purchase_3])

# %%
dfs
# Out:
#       Name Item Purchase  Cost
# 0       MD      Cat Food  22.5
# 1   Farman      Dog Food   2.5
# 2  Aidarus      CAt Food  20.5

# %%
df1.tail()
# Out:
#      State   area
# 4   pahang   6686
# 5    perak  36137
# 6   parlis  21035
# 7   penang    821
# 8            1048

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   9 non-null      object
#  1   area    9 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 272.0+ bytes

# %%
df1.describe()
# Out:
#                area
# count      9.000000
# mean   12355.555556
# std    11784.067391
# min      821.000000
# 25%     1664.000000
# 50%     9500.000000
# 75%    19210.000000
# max    36137.000000

# %%
df1
# Out:
#              State   area
# 0            johor  19210
# 1            kedah   9500
# 2           melaka  15099
# 3  negari Sembilan   1664
# 4           pahang   6686
# 5            perak  36137
# 6           parlis  21035
# 7           penang    821
# 8                    1048

# %%
a=df1.T
a
# Out:
#            0      1       2                3        4      5       6       7  \
# State  johor  kedah  melaka  negari Sembilan   pahang  perak  parlis  penang
# area   19210   9500   15099             1664     6686  36137   21035     821
#
#           8
# State
# area   1048

# %%
df11=df1.sort_values('area',ascending=False)

# %%
df11
# Out:
#              State   area
# 5            perak  36137
# 6           parlis  21035
# 0            johor  19210
# 2           melaka  15099
# 1            kedah   9500
# 4           pahang   6686
# 3  negari Sembilan   1664
# 8                    1048
# 7           penang    821

# %%
df11['area'].plot.bar()
plt.xticks(np.arange(13),(df11['State']))
plt.xlabel('Malaysian State')
plt.ylebel('Land area in $km^2$')
plt.tilte('Malaysian States by Land area')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-f4c979a4fee1> in <cell line: 2>()
#       1 df11['area'].plot.bar()
# ----> 2 plt.xticks(np.arange(13),(df11['State']))
#       3 plt.xlabel('Malaysian State')
#       4 plt.ylebel('Land area in $km^2$')
#       5 plt.tilte('Malaysian States by Land area')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in xticks(ticks, labels, minor, **kwargs)
#    1891             l._internal_update(kwargs)
#    1892     else:
# -> 1893         labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1894
#    1895     return locs, labels
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     295                 f"for the old name will be dropped %(removal)s.")
#     296             kwargs[new] = kwargs.pop(old)
# --> 297         return func(*args, **kwargs)
#     298
#     299     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1967             # remove all tick labels, so only error for > 0 labels
#    1968             if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969                 raise ValueError(
#    1970                     "The number of FixedLocator locations"
#    1971                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (13), usually from a call to set_ticks, does not match the number of labels (9).
